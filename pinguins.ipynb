# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv('pinguins.csv',  delimiter=';')

# %%
tabela.head()
# Out:
#    Espece       Ilha  largura do bico  profundidade do bico  \
# 0  Adelie  Torgersen             39.1                  18.7
# 1  Adelie  Torgersen             39.5                  17.4
# 2  Adelie  Torgersen             40.3                  18.0
# 3  Adelie  Torgersen              NaN                   NaN
# 4  Adelie  Torgersen             36.7                  19.3
#
#    profundidade do bico.1  massa corporal    sexo
# 0                   181.0          3750.0    male
# 1                   186.0          3800.0  female
# 2                   195.0          3250.0  female
# 3                     NaN             NaN     NaN
# 4                   193.0          3450.0  female

# %%
tabela.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Espece                  344 non-null    object
#  1   Ilha                    344 non-null    object
#  2   largura do bico         342 non-null    float64
#  3   profundidade do bico    342 non-null    float64
#  4   profundidade do bico.1  342 non-null    float64
#  5   massa corporal          342 non-null    float64
#  6   sexo                    333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# Verificar dados ausentes
missing_data = tabela.isnull().sum()
print(missing_data)
# Out:
# Espece                     0
# Ilha                       0
# largura do bico            2
# profundidade do bico       2
# profundidade do bico.1     2
# massa corporal             2
# sexo                      11
# dtype: int64

# %%
# Pinguins com dados ausentes
penguins_missing = tabela[tabela.isnull().any(axis=1)]
print(penguins_missing)
# Out:
#      Espece       Ilha  largura do bico  profundidade do bico  \
# 3    Adelie  Torgersen              NaN                   NaN
# 8    Adelie  Torgersen             34.1                  18.1
# 9    Adelie  Torgersen             42.0                  20.2
# 10   Adelie  Torgersen             37.8                  17.1
# 11   Adelie  Torgersen             37.8                  17.3
# 47   Adelie      Dream             37.5                  18.9
# 178  Gentoo     Biscoe             44.5                  14.3
# 218  Gentoo     Biscoe             46.2                  14.4
# 256  Gentoo     Biscoe             47.3                  13.8
# 268  Gentoo     Biscoe             44.5                  15.7
# 271  Gentoo     Biscoe              NaN                   NaN
#
#      profundidade do bico.1  massa corporal sexo
# 3                       NaN             NaN  NaN
# 8                     193.0          3475.0  NaN
# 9                     190.0          4250.0  NaN
# ...

# %%
# Contar pinguins por ilha
island_counts = tabela['Ilha'].value_counts()
print(island_counts)
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: Ilha, dtype: int64

# %%
# Contar pinguins por espécie
species_counts = tabela['Espece'].value_counts()
print(species_counts)
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: Espece, dtype: int64

# %%
# Pairplot para explorar relações entre medidas e espécies
sns.pairplot(tabela, hue='Espece')
plt.show()

# %%
# FacetGrid para explorar relações entre medidas e sexo dentro de cada espécie
g = sns.FacetGrid(tabela, col="Espece", hue="sexo", height=4, aspect=1)
g.map_dataframe(sns.scatterplot, x='profundidade do bico', y='profundidade do bico.1')
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(tabela, col="Espece", hue="sexo", height=4, aspect=1)
g.map_dataframe(sns.scatterplot, x='largura do bico', y='massa corporal')
g.add_legend()
plt.show()
